# %% [markdown]
# <a href="https://colab.research.google.com/github/SoftwareEngineeringWoman/Python/blob/main/Google_Python_Learnings.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello Saira!")
# Out:
# Hello Saira!

# %%
print(11)
# Out:
# 11

# %%
3+4
# Out:
# 7

# %%
country= 'India'
age=33
print(country)
print(age)
# Out:
# India
# 33

# %%
10*3==40
# Out:
# False

# %%
# Conditional statements

if age>=18:
  print('Adult')
else:
  print('Minor')
# Out:
# Adult

# %%
# Loops
for number in [1,2,3,4,5]:
  print(number)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
my_list=[2,6,8]

for x in my_list:
  print(x/2)
# Out:
# 1.0
# 3.0
# 4.0

# %%
# Functions
def is_adult(age):
  if age>=18:
    print('Adult')
  else:
    print('Minor')

# %%
# Use the function that was just created.
is_adult(17)
# Out:
# Minor

# %%
# Use the built-in sorted() function.
# https://www.geeksforgeeks.org/python/python-built-in-functions/
new_list=[2,6,3,8]

sorted(new_list)
# Out:
# [2, 3, 6, 8]

# %%
# Import statements.
import warnings
warnings.filterwarnings('ignore')

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import seaborn as sns

# %%
# Create a list.

my_list=[10,'gold', 'doll']

# %%
# Use the helper function to calculate F1 score used in the following graphics.
def f1_score(precision, recall):
    score = 2*precision*recall / (precision + recall)
    score = np.nan_to_num(score)

    return score

# %%
# Generate a graph of F1 score for different precision and recall scores.
x = np.linspace(0, 1, 101)
y = np.linspace(0, 1, 101)
X, Y = np.meshgrid(x, y)
Z = f1_score(X, Y)
fig = plt.figure()
fig.set_size_inches(10, 10)
ax = plt.axes(projection='3d')
ax.plot_surface(X, Y, Z, rstride=2, cstride=3, cmap='plasma')

ax.set_title('$F_{1}$ of precision, recall', size=18)
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
ax.view_init(35, -65)

# %%
#OOPS

# %%
# Assign a string to a variable and check its type.
MAGIC='ABRA CADABRA'
print(type(MAGIC))
# Out:
# <class 'str'>

# %%
# Use the swapcase() string method to convert from caps to lowercase.
MAGIC='ABRA CADABRA'
MAGIC=MAGIC.swapcase()
MAGIC
# Out:
# 'abra cadabra'

# %%
# Use the replace() string method to replace some letters with other letters.

MAGIC='ABRA CADABRA'
MAGIC=MAGIC.replace('A','O')
MAGIC
# Out:
# 'OBRO CODOBRO'

# %%
# Use the split() string method to split the string into two strings.
MAGIC='ABRA CADABRA'
MAGIC=MAGIC.split()
MAGIC
# Out:
# ['ABRA', 'CADABRA']

# %%
# Set up the cell to create the `planets` dataframe.
# (This cell was not shown in the instructional video.)
import pandas as pd
data = [['Mercury', 2440, 0], ['Venus', 6052, 0,], ['Earth', 6371, 1],
        ['Mars', 3390, 2], ['Jupiter', 69911, 80], ['Saturn', 58232, 83],
        ['Uranus', 25362, 27], ['Neptune', 24622, 14]
]

cols = ['Planet', 'radius_km', 'moons']

planets = pd.DataFrame(data, columns=cols)

# %%
# Display the `planets` dataframe.

planets
# Out:
#     Planet  radius_km  moons
# 0  Mercury       2440      0
# 1    Venus       6052      0
# 2    Earth       6371      1
# 3     Mars       3390      2
# 4  Jupiter      69911     80
# 5   Saturn      58232     83
# 6   Uranus      25362     27
# 7  Neptune      24622     14

# %%
# Use the shape dataframe attribute to check the number of rows and columns.
planets.shape
# Out:
# (8, 3)

# %%
# Use the columns dataframe attribute to check column names.
planets.columns
# Out:
# Index(['Planet', 'radius_km', 'moons'], dtype='object')

# %%
#Variables & data types

# %%
# Assign a list containing players' ages.

age_p=[34,67,56,32]
# Find the maximum age and assign to `max_age` variable.
max_age=max(age_p)
max_age
# Out:
# 67

# %%
# Convert `max_age` to a string.
max_age=str(max_age)
max_age
# Out:
# '67'

# %%
# Reassign the value of `max_age`.
max_age = 'ninety-nine'
max_age
# Out:
# 'ninety-nine'

# %%
# Find the minimum age and assign to `min_age` variable.
min_age = min(age_p)
min_age

# Subtract `min_age` from `max_age`
max_age - min_age
min_age
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2764976693.py in <cell line: 0>()
#       4
#       5 # Subtract `min_age` from `max_age`
# ----> 6 max_age - min_age
#       7 min_age
#
# TypeError: unsupported operand type(s) for -: 'str' and 'int'

# %%
# Explicit conversion (The str() function converts a number to a string.)
print("2 + 2 = " + str(2 + 2))

# %%
#Class were Spaceship, then attributes might be:

    #kind
    #speed
    #tractor_beam

#These attributes could be accessed by typing:

    #Spaceship.name
    #Spaceship.kind
    #Spaceship.speed
    #Spaceship.tractor_beam

#Methods of the Spaceship class might be:

    #warp()

    #tractor()

#These methods could be used by typing:

    #Spaceship.warp()

    #Spaceship.tractor()




class Spaceship:
   # Class attribute
   tractor_beam = 'off'

   # Instance attributes
   def __init__(self, name, kind):
       self.name = name
       self.kind = kind
       self.speed = None

  # Instance methods
   def warp(self, warp):
       self.speed = warp
       print(f'Warp {warp}, engage!')

   def tractor(self):
       if self.tractor_beam == 'off':
           self.tractor_beam = 'on'
           print('Tractor beam on.')
       else:
           self.tractor_beam = 'off'
           print('Tractor beam off')


# Create an instance of the Spaceship class (i.e. "instantiate")
ship = Spaceship('Mockingbird','rescue frigate')

# Check ship's name
print(ship.name)

# Check what kind of ship it is
print(ship.kind)

# Check tractor beam status
print(ship.tractor_beam)

# %%
 #The warp() method to set the warp speed to seven. Then it checks the current speed of the ship using the speed attribute.
 ship.warp(7)
 print(ship.speed)

# %%
 #The tractor() method to toggle the tractor beam. Then it checks the current status of the tractor beam using the tractor_beam attribute.
 ship.tractor()
 print(ship.tractor_beam)

# %% [markdown]
# Here are some of the basics:
#
# Variables: Represent data stored as strings, tuples, dictionaries, lists, and objects (note: future readings explain these categories)
#
# Example: student_name
#
# Keywords: Special words that are reserved for specific purposes and that can only be used for those purposes
#
# Examples:
#
# in
#
# not
#
# or
#
# for
#
# while
#
# return
#
# Operators: Symbols that perform operations on objects and values
#
# Examples:
#
# +     Addition
#
# -     Subtraction
#
# *     Multiplication
#
# /     Division
#
# **   Exponentiation
#
# %     Modulo (returns the remainder after a division). Example: 10 % 3 = 1
#
# //   Floor division (divides the first operand by the second operand and rounds the result down to the nearest integer. Example: 5 // 2 = 2
#
# >     Greater than (returns a Boolean of whether the left operand is greater than the right operand)
#
# <     Less than (returns a Boolean of whether the left operand is less than the right operand)
#
# ==   Equality (returns a Boolean of whether the left operand is equal to the right operand)
#
# Expressions: A combination of numbers, symbols, and variables to compute and return a result upon evaluation
#
# Example: [1, 2, 3] + [2, 4, 6]
#
#
# Functions: A group of related statements to perform a task and return a value

# %%
def to_celsius(x):
   '''Convert Fahrenheit to Celsius'''
   return (x-32) * 5/9

to_celsius(75)

# %% [markdown]
# https://docs.python.org/3/library/functions.html#built-in-functions
# https://docs.python.org/3/library/

# %% [markdown]
# return vs. print
#  Return statements give you a result that you can use for something else. It doesn’t have to be something that prints when the function is run.
#  Print statements print something to the console and nothing more.
#  Think of it like this: a return statement is like your brother going to the market and bringing you back a bag of potatoes. A print statement is like your brother going to the market, coming home, and telling you what kind of potatoes were for sale.
#  With the return statement, you have some potatoes to cook.
#  With the print statement, you just know what potatoes are available, but you don’t have any potatoes.
#
# Functions vs. methods
# Functions and methods are very similar, but there are a few key differences. Methods are a specific type of function. They are functions that belong to a class. This means that you can use them—or “call” them—by using dot notation.

# %%
#Method example:
my_string = 'The eagles filled the sky.'
my_string.split()

#Function example:
 sum([6, 3])
9

# %%
#Conditionals syntax
x = 8
if x > 5:
   print('x is greater than five')
elif x < 5:
   print('x is less than five')
else:
   print('x is equal to five')

# %%
def greater_than_ten(x):
    if x > 10:
        return True
    else:
        return False

print(greater_than_ten(15))
print(greater_than_ten(2))

#2nd way

def greater_than_ten(x):
    if x > 10:
        return True
    return False

print(greater_than_ten(15))
print(greater_than_ten(2))

# %%
#While loops
# Instantiate a counter.
x = 0

# Create a while loop that prints "not there yet," increments x by 1, a
# and prints x until x reaches 5.
while x < 5:
    print('Not there yet, x=' + str(x))
    x = x + 1
    print('x=' + str(x))
# Out:
# Not there yet, x=0
# x=1
# Not there yet, x=1
# x=2
# Not there yet, x=2
# x=3
# Not there yet, x=3
# x=4
# Not there yet, x=4
# x=5

# %%
# Import the random module to be able to create a (pseudo) random number.
import random

number = random.randint(1,25)                   # Generate random number
number_of_guesses = 0                           # Instantiate guess counter

while number_of_guesses < 5:
    print('Guess a number between 1 and 25: ')  # Tell user to guess number
    guess = input()                             # Produce the user input field
    guess = int(guess)                          # Convert guess to integer
    number_of_guesses += 1                      # Increment guess count by 1

    if guess == number:                         # Break while loop if guess is correct
        break
    elif number_of_guesses == 5:                # Break while loop if guess limit reached
        break
    else:                                       # Tell user to try again
        print('Nope! Try again.')

# Message to display if correct
if guess == number:
    print('Correct! You guessed the number in ' + str(number_of_guesses) + ' tries!')
# Message to display after 5 unsuccessful guesses
else:
    print('You did not guess the number. The number was ' + str(number) + '.')
# Out:
# Guess a number between 1 and 25:
# 5
# Nope! Try again.
# Guess a number between 1 and 25:
# 7
# Nope! Try again.
# Guess a number between 1 and 25:
# 9
# Nope! Try again.
# Guess a number between 1 and 25:
# 6
# Nope! Try again.
# Guess a number between 1 and 25:
# 3
# Correct! You guessed the number in 5 tries!

# %%
#loops

# Example of for loop with range() function
for x in range(5):
    print(x)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
#Loops with multiple range parameters

# Use a for loop to calculate 9!
product = 1
for n in range(1, 10):
    product = product * n

print(product)
# Out:
# 362880

# %%
# Define a function that converts Fahrenheit to Celsius.
def to_celsius(x):
     return (x-32) * 5/9

# Create a table of Celsius-->Fahrenheit conversions every 10 degrees, 0-100
for x in range(0, 101, 10):
     print(x, to_celsius(x))
# Out:
# 0 -17.77777777777778
# 10 -12.222222222222221
# 20 -6.666666666666667
# 30 -1.1111111111111112
# 40 4.444444444444445
# 50 10.0
# 60 15.555555555555555
# 70 21.11111111111111
# 80 26.666666666666668
# 90 32.22222222222222
# 100 37.77777777777778

# %%
#Work with strings
# Adding strings will combine them.
'Hello' + 'world'
# Out:
# 'Helloworld'

# %%
# Including a whitespace when combining strings
'Hello' + ' ' + 'world'
# Out:
# 'Hello world'

# %%
# Variables containing strings can be added.
greeting_1 = 'Hello '
greeting_2 = 'world'
greeting_1 + greeting_2
# Out:
# 'Hello world'

# %%
# Strings can be multiplied by integers.
danger = 'Danger! '
danger * 3
# Out:
# 'Danger! Danger! Danger! '

# %%
# Alternate single and double quotes to include one or the other in your string.
quote = '"Thank you for pressing the self-destruct button."'
print(quote)
# Out:
# "Thank you for pressing the self-destruct button."

# %%
# \ is an escape character that modifies the character that follows it.
quote = "\"It's dangerous to go alone!\""
print(quote)
# Out:
# "It's dangerous to go alone!"

# %%
# \n creates a newline.
greeting = "Good day,\nsir."
print(greeting)
# Out:
# Good day,
# sir.

# %%
# Using escape character (\) lets you express the newline symbol within a string.
newline = "\\n represents a newline in Python."
print(newline)
# Out:
# \n represents a newline in Python.

# %%
# You can loop over strings.
python = 'Python'
for letter in python:
    print(letter + 'ut')
# Out:
# Put
# yut
# tut
# hut
# out
# nut

# %%
#string slicing

# %%
# The index() method returns index of character's first occurrence in string.
pets = 'cats and dogs'
pets.index('s')
# Out:
# 3

# %%
# Access the character at a given index of a string.
name = 'Jolene'
name[0]
# Out:
# 'J'

# %%
# Access the character at a given index of a string.
name[5]

# Negative indexing begins at the end of the string.
sentence = 'A man, a plan, a canal, Panama!'
sentence[-1]

# Negative indexing begins at the end of the string.
sentence[-2]
# Out:
# 'a'

# %%
# Access a substring by using a slice.
color = 'orange'
color[1:4]
# Out:
# 'ran'

# %%
# Omitting the first value of the slice implies a value of 0.
fruit = 'pineapple'
fruit[:4]
# Out:
# 'pine'

# %%
# Omitting the last value of the slice implies a value of len(string).
fruit[4:]
# Out:
# 'apple'

# %%
# The `in` keyword returns Boolean of whether substring is in string.
'banana' in fruit
# Out:
# False

# %%
# The `in` keyword returns Boolean of whether substring is in string.
'apple' in fruit
# Out:
# True

# %%
#format strings

# Use format() method to insert values into your string, indicated by braces.
name = 'Manuel'
number = 3
print('Hello {}, your lucky number is {}.'.format(name, number))
# Out:
# Hello Manuel, your lucky number is 3.

# %%
# You can assign names to designate how you want values to be inserted.
name = 'Manuel'
number = 3
print('Hello {name}, your lucky number is {num}.'.format(num=number, name=name))
# Out:
# Hello Manuel, your lucky number is 3.

# %%
# You can use argument indices to designate how you want values to be inserted.
print('Hello {1}, your lucky number is {0}.'.format(number, name))
# Out:
# Hello Manuel, your lucky number is 3.

# %%
# Example inserting prices into string
price = 7.75
with_tax = price * 1.07
print('Base price: ${} USD. \nWith tax: ${} USD.'.format(price, with_tax))
# Out:
# Base price: $7.75 USD.
# With tax: $8.2925 USD.

# %%
# Use :.2f to round a float value to two places beyond the decimal.
print('Base price: ${:.2f} USD. \nWith tax: ${:.2f} USD.'.format(price, with_tax))
# Out:
# Base price: $7.75 USD.
# With tax: $8.29 USD.

# %%
# Define a function that converts Fahrenheit to Celsius.
def to_celsius(x):
    return (x-32) * 5/9

# Create a temperature conversion table using string formatting
for x in range(0, 101, 10):
    print("{:>3} F | {:>6.2f} C".format(x, to_celsius(x)))
# Out:
#   0 F | -17.78 C
#  10 F | -12.22 C
#  20 F |  -6.67 C
#  30 F |  -1.11 C
#  40 F |   4.44 C
#  50 F |  10.00 C
#  60 F |  15.56 C
#  70 F |  21.11 C
#  80 F |  26.67 C
#  90 F |  32.22 C
# 100 F |  37.78 C

# %%
#while loop
#break & continue: It is possible to end a loop even if the conditional statement is still true. To do this, use a break statement.

x = 1
i = 0
while x < 100:
   if i == 5:
       break
   print(i, x)
   x = x*2
   i += 1
# Out:
# 0 1
# 1 2
# 2 4
# 3 8
# 4 16

# %%
#It’s also possible to skip an iteration of the loop without executing the rest of the code inside the loop for the current iteration.
#To do this, use a continue statement.

i = 0
while i < 10:
    if i % 3 != 0:
        print(i)
        i += 1
        continue
    i += 1
# Out:
# 1
# 2
# 4
# 5
# 7
# 8

# %%
# Assign `candy_purchased` to an initial value of 0 to act as a counter
candy_purchased = 0

# Create an iterative statement using `while` and `candy_purchased`
# Display how many purchases have been made with each iteration

while candy_purchased <= 5:
    print('Candy purchased: ' + str(candy_purchased))
    # Increment the candy_purchased counter
    candy_purchased += 1
# Out:
# Candy purchased: 0
# Candy purchased: 1
# Candy purchased: 2
# Candy purchased: 3
# Candy purchased: 4
# Candy purchased: 5

# %%
#Iterate using while and if
candy_purchased = 0
#Write a while loop where candy_purchased begins at 0 and stops after 100 purchases have been made. Your code must:
#Increment candy_purchased by one with each iteration
#Print 'Candy purchased: {number}' only when a multiple of 10 purchases have been made

while candy_purchased <= 100:
    if candy_purchased % 10 == 0:
        print('Candy purchased: ' + str(candy_purchased))
    candy_purchased += 1
# Out:
# Candy purchased: 0
# Candy purchased: 10
# Candy purchased: 20
# Candy purchased: 30
# Candy purchased: 40
# Candy purchased: 50
# Candy purchased: 60
# Candy purchased: 70
# Candy purchased: 80
# Candy purchased: 90
# Candy purchased: 100

# %%
#Create a webpage timer function

from time import sleep

n = 3
while n >= 0:
    print(n)
    sleep(1)    # Execution pauses for 1 second
    n = n - 1   # Decrement n by 1
# Out:
# 3
# 2
# 1
# 0

# %%
#more than one way to solve this problem

from time import sleep

### YOUR CODE HERE ###
mins = 10

while mins >= 0:
    if mins == 5:
        print('Place your reservation soon! 5 minutes remaining.')
    elif mins == 2:
        print('Don\'t lose your seats! 2 minutes remaining.')
    elif mins == 0:
        print('User timed out.')
    else:
        print(mins)
    mins -=1
    sleep(1)
# Out:
# 10
# 9
# 8
# 7
# 6
# Place your reservation soon! 5 minutes remaining.
# 4
# 3
# Don't lose your seats! 2 minutes remaining.
# 1
# User timed out.

# %% [markdown]
# some examples of iterable data types include:
#
# Strings: ‘chimichurri’
#
# Lists: [1, 2, 3, 4, 5, 6]
#
# Tuples: (1, 2, 3, 4, 5)
#
# Dictionaries: {‘Name’: ‘Anita’, ‘Age’: 77}
#
# Sets: {1, 4, 14, 33}
#
# For loop syntax :

# %%
num = 5
y = [1, 2, 3]
for num in y:
   print(num)

print(num)
# Out:
# 1
# 2
# 3
# 3

# %% [markdown]
# Notice that num exists as a variable before the for loop begins. The for loop’s first iteration reassigns its value with that of the first element in the sequence. This reassignment occurs with each iteration of the loop. When the loop terminates, the variable persists, and it contains the value it had after the final iteration of the loop.

# %%
#The range() function


for i in range(3):
   print(i)
# Out:
# 0
# 1
# 2

# %%
for n in range(2, 5):
   print(n)
# Out:
# 2
# 3
# 4

# %%
for even_num in range(2, 11, 2):
   print(even_num)
# Out:
# 2
# 4
# 6
# 8
# 10

# %%
#Nested loops

students = [['Igor', 'Sokolov'], ['Riko', 'Miyazaki'], ['Tuva', 'Johansen']]
for student in students:
   for name in student:
       print(name)
   print()
# Out:
# Igor
# Sokolov
#
# Riko
# Miyazaki
#
# Tuva
# Johansen

# %%
#Iterating with if, elif, and else

### YOUR CODE HERE ###
def score_counter(score_list):
    negative_scores = 0
    neutral_scores = 0
    positive_scores = 0

    for score in score_list:
        if score >= 9:
            positive_scores += 1
        elif score >= 6:
            neutral_scores += 1
        else:
            negative_scores += 1

    print('Negative:', negative_scores)
    print('Neutral:', neutral_scores)
    print('Positive:', positive_scores)

# %%
# RUN THIS CELL TO TEST YOUR FUNCTION

import random
random.seed(42)

possible_scores = list(range(1,11))
score_list1 = random.choices(possible_scores, weights=[8,8,8,8,8,3,3,4,20,30], k=10)
score_list2 = random.choices(possible_scores, weights=[1,2,3,4,5,10,15,15,7,9], k=450)
score_list3 = random.choices(possible_scores, weights=[1,2,3,4,4,5,5,10,15,25], k=10000)

print('Test 1:')            # SHOULD OUTPUT (neg, neut, pos):
score_counter(score_list1)  # 5, 1, 4
print('\nTest 2:')
score_counter(score_list2)  # 85, 253, 112
print('\nTest 3:')
score_counter(score_list3)  # 1935, 2652, 5413
# Out:
# Test 1:
# Negative: 5
# Neutral: 1
# Positive: 4
#
# Test 2:
# Negative: 85
# Neutral: 253
# Positive: 112
#
# Test 3:
# Negative: 1935
# Neutral: 2652
# Positive: 5413

# %%
#Create a for loop using if, not, and in

#In this task, you are provided with two lists: a list of verified customer IDs and a list of all IDs that left feedback scores.
#You must validate the data by cross-checking the lists against each other.

### YOUR CODE HERE ###
def id_validator(verified_ids, feedback_ids):
    unverified_feedback = 0
    for id in feedback_ids:
        if id not in verified_ids:
            unverified_feedback += 1
    percent_unverified = unverified_feedback/len(feedback_ids)*100
    print(unverified_feedback, 'of', len(feedback_ids), 'IDs unverified.')
    print(str(round(percent_unverified, 2)) + '% unverified.')

# %%
# RUN THIS CELL TO TEST YOUR FUNCTION
import ada_c2_labs as lab

# TEST SCENARIOS:                                   # SHOULD OUTPUT:
print('Test 1:')
ver1, fb1 = lab.lists_gen(8, 20, 15, 15)            # 4 of 15 IDs unverified.
id_validator(ver1, fb1)                             # 26.67% unverified.

print('\nTest 2:')
ver2, fb2 = lab.lists_gen(8, 1000, 900, 600)        # 357 of 900 IDs unverified.
id_validator(ver2, fb2)                             # 39.67% unverified.

print('\nTest 3:')
ver3, fb3 = lab.lists_gen(8, 15000, 14925, 13788)   # 1208 of 14925 IDs unverified.
id_validator(ver3, fb3)                             # 8.09% unverified.
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipython-input-2810796330.py in <cell line: 0>()
#       1 # RUN THIS CELL TO TEST YOUR FUNCTION
# ----> 2 import ada_c2_labs as lab
#       3
#       4 # TEST SCENARIOS:                                   # SHOULD OUTPUT:
#       5 print('Test 1:')
#
# ModuleNotFoundError: No module named 'ada_c2_labs'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
#Create a nested loop

#You've been asked to calculate the total value of all purchases made by each customer to understand how many customers have spent $100+.


### YOUR CODE HERE ###

def purchases_100(sales):
    count = 0                           # Set a counter of totals > 100
    for customer in sales:              # Loop over each inner list
        customer_total = 0              # Set 0 value of purchases for the inner list
        for purchase in customer:       # For price in inner list:
            customer_total += purchase  # Add the price to value of purchases for inner list
        if customer_total >= 100:       # After looping over all prices in inner list, if
                                        # total >= 100
            count+=1                    # Increment the counter
    return count

# %%
# RUN THIS CELL TO TEST YOUR FUNCTION
import ada_c2_labs as lab
sales1 = lab.sales_data_generator(n_customers=10, seed=1)   # SHOULD OUTPUT:
print('Test 1:', purchases_100(sales1))                     # 5

sales2 = lab.sales_data_generator(n_customers=150, seed=18)
print('Test 2:', purchases_100(sales2))                     # 46

sales3 = lab.sales_data_generator(n_customers=1275, seed=42)
print('Test 3:', purchases_100(sales3))                     # 470
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3434935608.py in <cell line: 0>()
#       1 # RUN THIS CELL TO TEST YOUR FUNCTION
#       2 #import ada_c2_labs as lab
# ----> 3 sales1 = lab.sales_data_generator(n_customers=10, seed=1)   # SHOULD OUTPUT:
#       4 print('Test 1:', purchases_100(sales1))                     # 5
#       5
#
# NameError: name 'lab' is not defined

# %%
#Work with strings
# This is an immutable data type, which means the values can never be altered or updated.
#Even though strings are immutable, we can still do a lot with them. For instance, we can concatenate them.

#String indexing
my_string = 'Mississippi half-step'
print(my_string[0])

my_list = [1, 'unladen', 'swallow']
print(my_list[1])

print(my_list[-1])
# Out:
# M
# unladen
# swallow

# %%
#Slicing

new_string = 'pining for the fjords'
print(new_string[0:3])
print(new_string[:3])
# Out:
# pin
# pin

# %%
new_string = 'pining for the fjords'
print(new_string[6:21])
print(new_string[6:])
print(len(new_string))
# Out:
#  for the fjords
#  for the fjords
# 21

# %%
new_string = 'pining for the fjords'
print(new_string[6:100])
# Out:
#  for the fjords

# %%
#String formatting

x = 'values'
y = 100

print('''String formatting lets you insert {} into strings.
They can even be numbers, like {}.'''.format(x, y))
# Out:
# String formatting lets you insert values into strings.
# They can even be numbers, like 100.

# %%
var_a = 'A'
var_b = 'B'
print('{a}, {b}'.format(b=var_b, a=var_a))
# Out:
# A, B

# %%
var_a = 'A'
var_b = 'B'
print('{1}, {0}'.format(var_a, var_b))
print('{0}, {1}'.format(var_a, var_b))
# Out:
# B, A
# A, B

# %%
#Literal string interpolation (f-strings)

var_a = 1
var_b = 2
print(f'{var_a} + {var_b}')
print(f'{var_a + var_b}')
print(f'var_a = {var_a} \nvar_b = {var_b}')
# Out:
# 1 + 2
# 3
# var_a = 1
# var_b = 2

# %% [markdown]
# **Float formatting options**
#
#
# In addition to inserting expressions into strings, string formatting can format their appearance. There are too many options to list here, but the
# Python string documentation
#  is a good place to review these techniques. Here are some of the most useful.
#
# To use these options, build your expression within braces as follows.
# The float variable is what’s being formatted
#
# A colon (:) separates what’s being formatted from the syntax used to format it
#
# .number indicates the desired precision
#
# A letter indicates the presentation type

# %%
num = 1000.987123
f'{num:.2f}'
# Out:
# '1000.99'

# %% [markdown]
# 'e'
#
# Scientific notation. For a given precision p, formats the number in scientific notation with the letter ‘e’ separating the coefficient from the exponent. The coefficient has one digit before and p digits after the decimal point, for a total of p + 1 significant digits. With no precision given, e uses a precision of 6 digits after the decimal point for float, and shows all coefficient digits for decimal.
#
# 'f'
#
# Fixed-point notation. For a given precision p, formats the number as a decimal number with exactly p digits following the decimal point.
#
# '%'
#
# Percentage. Multiplies the number by 100 and displays in fixed ('f') format, followed by a percent sign.

# %%
num = 1000.987123
print(f'{num:.3e}')

decimal = 0.2497856
print(f'{decimal:.4%}')
# Out:
# 1.001e+03
# 24.9786%

# %% [markdown]
# **String methods**

# %%
#str.count(sub[, start[, end]])
#Return the number of non-overlapping occurrences of substring sub in the range [start , end].


my_string = 'Happy birthday'

print(my_string.count('y'))
print(my_string.count('y', 2, 7))
# Out:
# 2
# 1

# %%
#str.find(sub)
#Return the lowest index in the string where substring sub is found. Return -1 if sub is not found.

my_string = 'Happy birthday'
my_string.find('birth')
# Out:
# 6

# %%
#str.join()
#Return a string which is the concatenation of the strings in iterable.
#The separator between elements is the string providing this method.

separator_string = ' '
iterable_of_strings = ['Happy', 'birthday', 'to', 'you']

separator_string.join(iterable_of_strings)
# Out:
# 'Happy birthday to you'

# %%
#str.partition(sep)

my_string = 'https://www.google.com/'

my_string.partition('.')
# Out:
# ('https://www', '.', 'google.com/')

# %%
#str.replace(old, new[, count])
#Return a copy of the string with all occurrences of substring old replaced by new.
#If the optional argument count is given, only the first count occurrences are replaced.

my_string = 'https://www.google.com/'

my_string.replace('google', 'youtube')
# Out:
# 'https://www.youtube.com/'

# %%
#str.split([sep])
#Return a list of the words in the string, using sep (optional) as the delimiter string.
#If no sep is given, whitespace characters are used as the delimiter.
#Any number of consecutive whitespaces would indicate a split point, so ' ' (a single whitespace)
#would split the same way as '   ' (two or more whitespaces).

my_string = 'Do you know the muffin man?'

my_string.split()
# Out:
# ['Do', 'you', 'know', 'the', 'muffin', 'man?']

# %%
#Regular expressions

#Regular expressions, also known as regex, refer to techniques that advanced data professionals use to modify and process string data
#Regex works by matching patterns in Python.
#It allows you to search for specific patterns of text within a string of text.
#Regex is used extensively in web scraping, text processing and cleaning, and data analysis.

#The first step in working with regular expressions is to import the re module.
#This module provides the tools necessary for working with regular expressions

import re

my_string = 'Three sad tigers swallowed wheat in a wheat field'

re.search('wall', my_string)
# Out:
# <re.Match object; span=(18, 22), match='wall'>

# %%
import re

my_string = 'Three sad tigers swallowed wheat in a wheat field'

re.search('[bms]ad', my_string)
# Out:
# <re.Match object; span=(6, 9), match='sad'>

# %%
#Check and change data types
# Your new task is collecting store data for future analysis.
#In this task, you're given a four-digit numeric store ID stored in a variable called store_id.

#Convert store_id to a string and store the result in the same variable.
##Confirm the type of store_id after the conversion.
store_id = 1101

# 1. ### YOUR CODE HERE ###
store_id = str(store_id)

# 2. ### YOUR CODE HERE ###
print(type(store_id))
# Out:
# <class 'str'>

# %%
#String concatenation
#As you continue gathering data, you realize that the store_id variable is actually the ZIP Code where the store is located,
#but the leading 0 has been cut off.
#Define a function called zip_checker that accepts the following argument:  zipcode - a string with either four or five characters
#Return:
#If zipcode has five characters, and the first two characters are NOT '00', return zipcode as a string. Otherwise, return 'Invalid ZIP Code.'. (ZIP Codes do not begin with 00 in the mainland U.S.)
#If zipcode has four characters and the first character is NOT '0', the function must add a zero to the beginning of the string and return the five-character zipcode as a string.
#If zipcode has four characters and the first character is '0', the function must return 'Invalid ZIP Code.'.

# %%
### YOUR CODE HERE ###
def zip_checker(zipcode):
    if len(zipcode) == 5:
        if zipcode[0:2] =='00':
            return 'Invalid ZIP Code.'
        else:
            return zipcode
    elif zipcode[0] != '0':
        zipcode = '0' + zipcode
        return zipcode
    else:
        return 'Invalid ZIP Code.'

# %%
print(zip_checker('02806'))     # Should return 02806.
print(zip_checker('2806'))      # Should return 02806.
print(zip_checker('0280'))      # Should return 'Invalid ZIP Code.'
print(zip_checker('00280'))     # Should return 'Invalid ZIP Code.'
# Out:
# 02806
# 02806
# Invalid ZIP Code.
# Invalid ZIP Code.

# %%
#Extract the store ID
#Now imagine that you've been provided url, which is a URL containing the store's actual ID at the end of it.

#Extract the seven-character store ID from the end of url and assign the result to a variable called id.
#Print the contents of id.
url = "https://exampleURL1.com/r626c36"
# 1. ### YOUR CODE HERE ###
id = url[-7:]

# 2. ### YOUR CODE HERE ###
print(id)
# Out:
# r626c36

# %% [markdown]
# String extraction function
# You have many URLs that contain store IDs, but many of them are invalid—either because they use an invalid protocol (the beginning of the URL) or because the store ID is not seven characters long.
#
# The correct URL protocol is https: Anything else is invalid.
# A valid store ID must have exactly seven characters.
#
# Define a function called url_checker that accepts the following argument:
#
# url - a URL string
#
#
# Return:
# If both the protocol and the store ID are invalid:
# print two lines:
# '{protocol} is an invalid protocol.'
# '{store_id} is an invalid store ID.'
# If only the protocol is invalid:
# print:
# '{protocol} is an invalid protocol.'
# If only the store ID is invalid:
# print:
# '{store_id} is an invalid store ID.'
# If both the protocol and the store ID are valid, return the store ID.
# In the above cases, {protocol} is a string of the protocol and {store_id} is a string of the store ID.

# %%
# Sample valid URL for reference while writing your function:
url = 'https://exampleURL1.com/r626c36'

### YOUR CODE HERE ###
def url_checker(url):
    url = url.split('/')
    protocol = url[0]
    store_id = url[-1]
    # If both protocol and store_id bad
    if protocol != 'https:' and len(store_id) != 7:
        print(f'{protocol} is an invalid protocol.',
            f'\n{store_id} is an invalid store ID.')
    # If just protocol bad
    elif protocol != 'https:':
        print(f'{protocol} is an invalid protocol.')
    # If just store_id bad
    elif len(store_id) != 7:
        print(f'{store_id} is an invalid store ID.')
    # If all ok
    else:
        return store_id

# %%
                                                # Should return:
url_checker('http://exampleURL1.com/r626c3')    # 'http: is an invalid protocol.'
print()                                         # 'r626c3 is an invalid store ID.'

url_checker('ftps://exampleURL1.com/r626c36')   # 'ftps: is an invalid protocol.
print()
url_checker('https://exampleURL1.com/r626c3')   # 'r626c3 is an invalid store ID.'
print()
url_checker('https://exampleURL1.com/r626c36')  # 'r626c36'
# Out:
# http: is an invalid protocol.
# r626c3 is an invalid store ID.
#
# ftps: is an invalid protocol.
#
# r626c3 is an invalid store ID.
# 'r626c36'

# %% [markdown]
# **Introduction to lists**

# %%
#Can contain duplicate items
#Mutable: items can be modified, replaced, or removed
#Ordered: elements maintain the order in which they were added
#Index-based: items are accessed using their position (starting from 0)
#Can store mixed data types (integers, strings, booleans, even other lists)

# Assign a list using brackets, with elements separated by commas.
x = ["Now", "we", "are", "cooking", "with", 7, "ingredients"]

# Print element at index 3.
print(x[3])
# Out:
# cooking

# %%
# Access part of a list by slicing.
x[1:3]
# Out:
# ['we', 'are']

# %%
# Omitting the first value of the slice implies a value of 0.
x[:2]
# Out:
# ['Now', 'we']

# %%
# Omitting the last value of the slice implies a value of len(list).
x[2:]
# Out:
# ['are', 'cooking', 'with', 7, 'ingredients']

# %%
# Check the data type of an object using type() function.
type(x)
# Out:
# list

# %%
# The `in` keyword lets you check if a value is contained in the list.
x = ["Now", "we", "are", "cooking", "with", 7, "ingredients"]
"This" in x
# Out:
# False

# %% [markdown]
# **Modify the contents of a list**

# %%
# The append() method adds an element to the end of a list.
fruits = ['Pineapple', 'Banana', 'Apple', 'Melon']
fruits.append('Kiwi')
print(fruits)
# Out:
# ['Pineapple', 'Banana', 'Apple', 'Melon', 'Kiwi']

# %%
# The insert() method adds an element to a list at the specified index.
fruits.insert(1, 'Orange')
print(fruits)
# Out:
# ['Pineapple', 'Orange', 'Banana', 'Apple', 'Melon', 'Kiwi']

# %%
# The insert() method adds an element to a list at the specified index.
fruits.insert(0, 'Mango')
print(fruits)
# Out:
# ['Mango', 'Pineapple', 'Orange', 'Banana', 'Apple', 'Melon', 'Kiwi']

# %%
# The remove() method deletes the first occurrence of an element in a list.
fruits.remove('Banana')
print(fruits)
# Out:
# ['Mango', 'Pineapple', 'Orange', 'Apple', 'Melon', 'Kiwi']

# %%
# Trying to remove an element that doesn't exist results in an error.
fruits.remove('Strawberry')
print(fruits)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-1364586326.py in <cell line: 0>()
#       1 # Trying to remove an element that doesn't exist results in an error.
# ----> 2 fruits.remove('Strawberry')
#       3 print(fruits)
#
# ValueError: list.remove(x): x not in list

# %%
# The pop() method removes the element at a given index and returns it.
# If no index is given, it removes and returns the last element.
fruits.pop(2)
print(fruits)
# Out:
# ['Mango', 'Pineapple', 'Apple', 'Melon', 'Kiwi']

# %%
# Reassign the element at a given index with a new value.
fruits[1] = 'Mango'
print(fruits)
# Out:
# ['Mango', 'Mango', 'Apple', 'Melon', 'Kiwi']

# %%
# Strings are immutable because you need to reassign them to modify them.
power = '1.21'
power = power + ' gigawatts'
print(power)
# Out:
# 1.21 gigawatts

# %%
# You cannot reassign a specific character within a string.
power[0] = '2'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3554064476.py in <cell line: 0>()
#       1 # You cannot reassign a specific character within a string.
# ----> 2 power[0] = '2'
#
# TypeError: 'str' object does not support item assignment

# %%
# Lists are mutable because you can overwrite their elements
power = [1.21, 'gigawatts']
power[0] = 2.21
print(power)
# Out:
# [2.21, 'gigawatts']

# %% [markdown]
# **Introduction to tuples**
# ![Python DSA.png](data:image/png;base64,...)

# %% [markdown]
# https://www.geeksforgeeks.org/dsa/python-data-structures-and-algorithms/

# %%
#Using list() Constructor
a = list((1, 2, 3, 'apple', 4.5))
print(a)

b = list("GFG")
print(b)
# Out:
# [1, 2, 3, 'apple', 4.5]
# ['G', 'F', 'G']

# %% [markdown]
# Adding Elements into List
# We can add elements to a list using the following methods:
#
# - append(): Adds an element at the end of the list.
# - extend(): Adds multiple elements to the end of the list.
# - insert(): Adds an element at a specific position.
# - clear(): removes all items.

# %%
a = []

a.append(10)
print("After append(10):", a)

a.insert(0, 5)
print("After insert(0, 5):", a)

a.extend([15, 20, 25])
print("After extend([15, 20, 25]):", a)

a.clear()
print("After clear():", a)
# Out:
# After append(10): [10]
# After insert(0, 5): [5, 10]
# After extend([15, 20, 25]): [5, 10, 15, 20, 25]
# After clear(): []

# %% [markdown]
# Removing Elements from List
# We can remove elements from a list using:
#
# - remove(): Removes the first occurrence of an element.
# - pop(): Removes the element at a specific index or the last element if - no index is specified.
# - del statement: Deletes an element at a specified index.

# %%
a = [10, 20, 30, 40, 50]

a.remove(30)
print("After remove(30):", a)

popped_val = a.pop(1)
print("Popped element:", popped_val)
print("After pop(1):", a)

print(a)
del a[0]
print("After del a[0]:", a)
# Out:
# After remove(30): [10, 20, 40, 50]
# Popped element: 20
# After pop(1): [10, 40, 50]
# [10, 40, 50]
# After del a[0]: [40, 50]

# %% [markdown]
# Nested Lists
# A nested list is a list within another list, which is useful for representing matrices or tables. We can access nested elements by chaining indexes.

# %%
matrix = [ [1, 2, 3],
           [4, 5, 6],
           [7, 8, 9] ]
print(matrix[1][2])
# Out:
# 6

# %% [markdown]
# Iterate over a list in Python
#
# Using for Loop
#
# Using for Loop with range()
#
# Using while Loop
#
# Using enumerate()
#
# Using List Comprehension

# %%
#The most common approach is to iterate through a list using the FOR LOOP increment variable i:

a = [1, 3, 5, 7, 9]

# On each iteration val
# represents the current item/element
for val in a:
    print(val)

# %%
# Iterate through a list without using the index variable:

#Method 1: Explicitly iterating through the list using a common variable for each element rather than the index.

# Initializing the list
List = ["Geeks", 4, 'Geeks!']
​
# Using a common variable to access
# each element of the list
for ele in List:
    print(ele, end=" ")


#Method 2: The enumerate() method adds a counter to the list and returns it in a form of enumerate object
#which can be used to access elements of the list

# Initializing the list
List = ["Geeks", 4, 'Geeks!']
​
# Using enumerate()
for ele in enumerate(List):
    print(ele[1], end=" ")


#Method 3: Using the nditer() method in numpy to iterate over a list after converting them into an array.

# Importing required modules
import numpy

# Initializing the list
List = ["Geeks", 4, 'Geeks!']

# Converting to array
Array = numpy.array(List)

# Using enumerate
for ele in numpy.nditer(Array):
    print(ele, end=" ")

# %%
#Using for Loop with range()
#We can use the range() method with for loop to traverse the list.
#This method allow us to access elements by their index,
#which is useful if we need to know the position of an element or modify the list in place.

a = [1, 3, 5, 7, 9]

# Calculate the length of the list
n = len(a)

# Iterates over the indices from 0 to n-1 (i.e., 0 to 4)
for i in range(n):
    print(a[i])

# %%
#Using while Loop
#Here we are using a while loop to iterate through a list.
 #We first need to find the length of list using len(),
 #then start at index 0 and access each item by its index then incrementing the index by 1 after each iteration.

a = [1, 3, 5, 7, 9]

# Start from the first index
i = 0

# The loop runs till the last index (i.e., 4)
while i < len(a):
    print(a[i])
    i += 1

# %%
#Using enumerate()
#We can also use the enumerate() function to iterate through the list.
#This method provides both the index (i) and the value (val) of each element during the loop.


a = [1, 3, 5, 7, 9]
​
# Here, i and val reprsents index and value respectively
for i, val in enumerate(a):
    print (i, val)

# %%
#Using List Comprehension
#List comprehension is similar to for loop. It provides the shortest syntax for looping through list.

a = [1, 3, 5, 7, 9]

# On each iteration val is passed to print function
# And printed in the console.
[print(val) for val in a]

# %% [markdown]
# List Comprehension
# List comprehension is a concise way to create lists using a single line of code. It is useful for applying an operation or filter to items in an iterable, such as a list or range.

# %%
squares = [x**2 for x in range(1, 6)]
print(squares)
# Out:
# [1, 4, 9, 16, 25]

# %% [markdown]
# How Python Stores List Elements?
#
# In Python, a list doesn’t store actual values directly. Instead, it stores references (pointers) to objects in memory. This means numbers, strings and booleans are separate objects in memory and the list just keeps their addresses.
#
# That’s why modifying a mutable element (like another list or dictionary) can change the original object, while immutables remain unaffected.

# %% [markdown]
# ![python-list.webp](data:image/webp;base64,...)

# %%
a = [10, 20, "GfG", 40, True]
print(a)
print(a[0])
print(a[1])
print(a[2])

#The list a contains an integer (10, 20 and 40),
#a string ("GfG") and a boolean (True).
#Elements are accessed using indexing (a[0], a[1], etc.).
#Each element keeps its original type.
# Out:
# [10, 20, 'GfG', 40, True]
# 10
# 20
# GfG

# %% [markdown]
# List Questions

# %%
#List Traversal
#Q) You are given a list that contains integers. You need to print the elements of the list with a space between them.
#Note: Do not add a new line at the end.

arr = [54, 43, 2, 1, 5]

# Convert each number to string and join with spaces
print(" ".join(map(str, arr)), end="")


#map(str, arr) → converts each integer to a string.
#" ".join(...) → joins them with a space.
#end="" → ensures no extra newline is added at the end.
# Out:
# 54 43 2 1 5

# %% [markdown]
# - map(str, arr) → converts each integer to string → O(n).
#
# - " ".join(...) → concatenates all strings with spaces → O(n) (total characters processed proportional to sum of digits, but we approximate as O(n)).
#
# - Printing → O(n).
#
# - Time Complexity: O(n)
# - Space Complexity: O(n) (because of temporary strings created for conversion).

# %%
#loop based approach
arr = [54, 43, 2, 1, 5]

for i in range(len(arr)):
    # Print each element, but avoid space after the last element
    if i == len(arr) - 1:
        print(arr[i], end="")
    else:
        print(arr[i], end=" ")
# Out:
# 54 43 2 1 5

# %% [markdown]
# - Loop runs n times → O(n).
# - Each print call takes O(1) (amortized) → total O(n).
# - Time Complexity: O(n)
# - Space Complexity: O(1) (only uses loop variables, no extra list/strings).
#
#
#
# - join method → concise, slightly more memory use (O(n)).
# - Loop method → memory efficient (O(1)), but slightly more verbose.
#
# 👉 Both are O(n) in time, so for large lists, performance is very similar.

# %%
#Length of The List
#Q)You are given a list that contains integers. You need to return the length of the list.
#built in len approach
def get_length(arr):
    return len(arr)

# Example
arr = [54, 43, 2, 1, 5]
print(get_length(arr))  # Output: 5
# Out:
# 5

# %% [markdown]
# - In Python, a list object stores its length as metadata
#
# - So len(arr) simply reads that stored value, it doesn’t need to iterate.
#
#
# Complexity:
#
# - Time Complexity: O(1) → constant-time lookup.
#
# - Space Complexity: O(1) → no extra memory.

# %%
#loop based approach

def get_length(arr):
    count = 0
    for _ in arr:   # iterate through each element
        count += 1  # increment counter
    return count

# Example
arr = [54, 43, 2, 1, 5]
print(get_length(arr))  # Output: 5

# %% [markdown]
# How it works:
#
# - Iterates through each element once, incrementing a counter.
#
# - To finish counting, it must visit all n elements.
#
# Complexity:
#
# - Time Complexity: O(n) → grows linearly with number of elements.
#
# - Space Complexity: O(1) → just a counter variable.
#
# Conclusion
#
# - len(arr) is faster (O(1)) because Python keeps the length stored internally.
#
# - Manual loop is slower (O(n)), but useful for learning how length is determined conceptually.

# %% [markdown]
# Q3 sum list
#
# You are given a list that contains integers. You need to return the sum of the list.

# %%
#You can use the built-in sum() function:

def get_sum(arr):
    return sum(arr)

# Example
arr = [54, 43, 2, 1, 5]
print(get_sum(arr))  # Output: 105
# Out:
# 105

# %% [markdown]
# Time Complexity: O(n) → needs to iterate through all n elements once.
#
# Space Complexity: O(1) → no extra memory used.

# %%
#Approach 2: Manual loop (without sum)
def get_sum(arr):
    total = 0
    for num in arr:
        total += num
    return total

# %% [markdown]
# Time Complexity: O(n) → visits all elements once.
#
# Space Complexity: O(1) → uses only an accumulator variable.

# %%
#Recursive Approach
def recursive_sum(arr):
    # Base case: if list is empty
    if not arr:
        return 0
    # Recursive case: first element + sum of the rest
    return arr[0] + recursive_sum(arr[1:])

# Example
arr = [54, 43, 2, 1, 5]
print(recursive_sum(arr))  # Output: 105
# Out:
# 105

# %% [markdown]
# Time Complexity: O(n) → we process each element once.
#
# Space Complexity: O(n) → due to recursive call stack (function keeps track of each level until reaching the base case).

# %% [markdown]
# Q3)Decrement List Values
# You are given a list that contains integers. You need to decrement each element of the list by 1 and return the list.

# %%
#Using List Comprehension
def decrement_list(arr):
    return [x - 1 for x in arr]

# Example
arr = [54, 43, 2, 1, 5]
print(decrement_list(arr))  # Output: [53, 42, 1, 0, 4]
# Out:
# [53, 42, 1, 0, 4]

# %%
#Using a Loop (in-place update)
def decrement_list(arr):
    for i in range(len(arr)):
        arr[i] -= 1
    return arr

# Example
arr = [54, 43, 2, 1, 5]
print(decrement_list(arr))  # Output: [53, 42, 1, 0, 4]
# Out:
# [53, 42, 1, 0, 4]

# %%
R#ecursive Solution
def decrement_recursive(arr):
    # Base case: empty list
    if not arr:
        return []
    # Decrement first element + recurse on rest of list
    return [arr[0] - 1] + decrement_recursive(arr[1:])

# Example
arr = [54, 43, 2, 1, 5]
print(decrement_recursive(arr))  # Output: [53, 42, 1, 0, 4]

# %% [markdown]
# List Comprehension [x-1 for x in arr]	Time Complexity
# Space Complexity O(n)	O(n)	Creates a new list of size n.
#
#
# Loop (in-place) for i in range(len(arr)): arr[i] -= 1	Time Complexity
# Space Complexity O(n)	O(1)	Updates the original list directly, most memory-efficient.
#
#
# Recursive [arr[0]-1] + recurse(...)	Time Complexity
# Space Complexity O(n²)	O(n)	Each recursion copies lists when using +, so combining lists takes extra time. Stack depth = n.

# %% [markdown]
# Fastest & cleanest: List comprehension (O(n), O(n)).
#
# Most memory efficient: In-place loop (O(n), O(1)).
#
# Educational but inefficient: Recursive version (O(n²), O(n)) due to list concatenation overhead.

# %% [markdown]
# Q) Append To List
#
# You are given three inputs a, b, c. You need to create a list and append a, b, c to the list and then return that list.

# %%
#Using append()
def create_list_append(a, b, c):
    result = []
    result.append(a)
    result.append(b)
    result.append(c)
    return result

# Example
a, b, c = 1, 2, 3
print(create_list_append(a, b, c))  # Output: [1, 2, 3]


#Explanation:

#Start with an empty list result.

#Use append() to add each element.

#Return the final list.
# Out:
# [1, 2, 3]

# %%
#Using List Literal
def create_list_literal(a, b, c):
    return [a, b, c]

# Example
a, b, c = 1, 2, 3
print(create_list_literal(a, b, c))  # Output: [1, 2, 3]


#Explanation:
#Just create the list directly using square brackets.
#Most concise method.
# Out:
# [1, 2, 3]

# %%
#Using + Operator
def create_list_plus(a, b, c):
    result = [] + [a] + [b] + [c]
    return result

# Example
a, b, c = 1, 2, 3
print(create_list_plus(a, b, c))  # Output: [1, 2, 3]


#Explanation:
#Start with empty list.
#Concatenate each element wrapped in a list using +.

# %% [markdown]
# - Best method: List literal [a, b, c] → simple, fast, memory-efficient.
#
# - Good for incremental addition: append() → scales well if number of elements grows gradually.
#
# - Avoid + for larger lists → copies lists multiple times, slower.
#
#
# ![time complex list Q.png](data:image/png;base64,...)
